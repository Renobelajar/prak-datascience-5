# %% [markdown]
# LATIHAN DATA CLEANING & PROCESSING

# %%
harga = 7500000
diskon = 0.15 * harga
print(diskon)
# Out:
# 1125000.0

# %% [markdown]
# 1. Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# 2. Load Dataset

# %%
df = sns.load_dataset('titanic')

# %% [markdown]
# 3.
